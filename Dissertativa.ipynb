# %%
.Solucao dissertativa
1. Leia e armazene o numero n que se deseja multiplicar por 9 #Entrada
2. Subtrair n-1 e armazenar como o primeiro digito n1 #Processamento
3. Subtrair 10-n e armazenar como o segundo digito n2 #Processamento
4. Realize a expressao (n1 x 10) + n2 e armazene resultado final r #Processamento
5. Apresente r (o resultado final) e encerre o programa #Saida
